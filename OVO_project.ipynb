# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/OVO_project/
# Out:
# /content/drive/MyDrive/OVO_project

# %%
import json

# Charger le fichier JSON
with open('/content/drive/MyDrive/OVO_project/Task01_BrainTumour/dataset.json', 'r') as f:
    dataset_info = json.load(f)

# Extraire le dictionnaire des modalités
modalities = dataset_info['modality']
print(modalities)
# Out:
# {'0': 'FLAIR', '1': 'T1w', '2': 't1gd', '3': 'T2w'}

# %%
import sys
sys.path.append("/content/drive/MyDrive/OVO_project/")

# %%
# %run /content/drive/MyDrive/OVO_project/create_2D_database.py
#create_2D_database()
#database already created, no need to run that again

# %%
from example_2D_brain_label import example_2D_brain_label
example_2D_brain_label()

# %%
# from train_and_save_CNN import train_and_save_CNN
# train_and_save_CNN()
# not training again the CNN, model already stored thanks to this code
# to /content/drive/MyDrive/OVO_project/unet_brats.pth

# %%
from infer_train import infer_train
infer_train()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ...

# %%
from infer_test import infer_test

infer_test()
# Out:
# device is: cuda
# /content/drive/MyDrive/OVO_project/infer_test.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !pip install siren_pytorch #needed for the next part
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import os
import numpy as np
folder_path = r"/content/drive/MyDrive/OVO_project/flair_middle_train"
file_list = os.listdir(folder_path)
file_names = [k.split('.')[0] for k in file_list]
random_file = np.random.choice(np.array(file_names))
print(random_file)
# Out:
# BRATS_465

# %%
from solo_SIREN_train_infer import siren_compute
siren_compute(random_file)
# Out:
# Epoch 100/50000, Loss: 0.083556
# Epoch 200/50000, Loss: 0.031431
# Epoch 300/50000, Loss: 0.018645
# Epoch 400/50000, Loss: 0.012674
# Epoch 500/50000, Loss: 0.009359
# Epoch 600/50000, Loss: 0.007354
# Epoch 700/50000, Loss: 0.006045
# Epoch 800/50000, Loss: 0.005133
# Epoch 900/50000, Loss: 0.004462
# Epoch 1000/50000, Loss: 0.003949
# Epoch 1100/50000, Loss: 0.003546
# Epoch 1200/50000, Loss: 0.003222
# Epoch 1300/50000, Loss: 0.002957
# Epoch 1400/50000, Loss: 0.002737
# Epoch 1500/50000, Loss: 0.002553
# Epoch 1600/50000, Loss: 0.002396
# Epoch 1700/50000, Loss: 0.002261
# Epoch 1800/50000, Loss: 0.002144
# Epoch 1900/50000, Loss: 0.002042
# Epoch 2000/50000, Loss: 0.001953
# Epoch 2100/50000, Loss: 0.001874
# Epoch 2200/50000, Loss: 0.001803
# Epoch 2300/50000, Loss: 0.001740
# Epoch 2400/50000, Loss: 0.001683
# Epoch 2500/50000, Loss: 0.001632
# Epoch 2600/50000, Loss: 0.001585
# Epoch 2700/50000, Loss: 0.001543
# Epoch 2800/50000, Loss: 0.001504
# ...

# %%
from SINCO_pipeline import sinco_pipeline
sinco_pipeline(random_file)
# Out:
# Dimensions de l'image: 240x240
# cuda
# Epoch 100/50000 - Rec Loss: 0.170133, Seg Loss: 0.808841, Total Loss: 0.170214
# Epoch 200/50000 - Rec Loss: 0.059415, Seg Loss: 0.624579, Total Loss: 0.059478
# Epoch 300/50000 - Rec Loss: 0.032934, Seg Loss: 0.590654, Total Loss: 0.032993
# Epoch 400/50000 - Rec Loss: 0.021385, Seg Loss: 0.588245, Total Loss: 0.021444
# Epoch 500/50000 - Rec Loss: 0.015156, Seg Loss: 0.588832, Total Loss: 0.015215
# Epoch 600/50000 - Rec Loss: 0.011436, Seg Loss: 0.594651, Total Loss: 0.011496
# Epoch 700/50000 - Rec Loss: 0.009053, Seg Loss: 0.603150, Total Loss: 0.009113
# Epoch 800/50000 - Rec Loss: 0.007437, Seg Loss: 0.610805, Total Loss: 0.007498
# Epoch 900/50000 - Rec Loss: 0.006290, Seg Loss: 0.616264, Total Loss: 0.006351
# Epoch 1000/50000 - Rec Loss: 0.005445, Seg Loss: 0.620593, Total Loss: 0.005507
# Epoch 1100/50000 - Rec Loss: 0.004804, Seg Loss: 0.624161, Total Loss: 0.004867
# ...

# %%
from SSIM_PSNR_Dice_vs_lambda import compute_metrics
compute_metrics(random_file)
# Out:
# /content/drive/MyDrive/OVO_project/SSIM_PSNR_Dice_vs_lambda.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
